# %% [markdown]
# # ItemkNN

# %%
import pandas as pd
import numpy as np

# !gdown 1t592p6DEMqr7vWAunLGY_CKBpq8m6HZo

df = pd.read_csv('results_FC-Items.csv', sep = ';')

df
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1t592p6DEMqr7vWAunLGY_CKBpq8m6HZo
# To: /content/results_FC-Items.csv
# 100% 2.14k/2.14k [00:00<00:00, 2.87MB/s]
#     Unnamed: 0   k      RMSE         Time
# 0            0   1  1.182569  2062.436757
# 1            1   2  1.182569  1990.414500
# 2            2   3  1.117101  1911.058747
# 3            3   4  1.125437  1898.864502
# 4            4   5  1.176719  1899.286350
# 5            5   6  1.140648  2093.360917
# 6            6   7  1.143757  2444.426079
# 7            7   8  1.146395  1968.569144
# 8            8   9  1.148672  1904.483180
# 9            9  10  1.167147  1912.178363
# 10          10  11  1.182830  1908.138645
# 11          11  12  1.182821  1924.725323
# 12          12  13  1.171781  1933.877396
# 13          13  14  1.172073  1922.761936
# 14          14  15  1.172281  1929.048528
# 15          15  16  1.172447  1920.315657
# 16          16  17  1.172542  1911.282424
# ...

# %%
min_rmse = np.min(df['RMSE'])

df[df['RMSE'] == min_rmse]
# Out:
#    Unnamed: 0  k      RMSE         Time
# 2           2  3  1.117101  1911.058747

# %%
np.mean(df['Time'])/60
# Out:
# 32.57555034922905

# %% [markdown]
# # User

# %%
# !gdown 1yGGKQK-xjy417jH83w-TGebqo4D8KQmS

df2 = pd.read_csv('results_FC-Users.csv', sep = ';')

min_rmse2 = np.min(df2['RMSE'])

df2[df2['RMSE'] == min_rmse2]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yGGKQK-xjy417jH83w-TGebqo4D8KQmS
# To: /content/results_FC-Users.csv
# 100% 2.10k/2.10k [00:00<00:00, 1.59MB/s]
#    Unnamed: 0  k      RMSE         Time
# 0           0  1  1.162694  2270.384965

# %%
np.mean(df2['Time'])/60
# Out:
# 37.35533600794215

# %% [markdown]
# # Baseline

# %%
# !gdown 1jyjsdvcQireEUqiy8O0aE-kgMkFYEy5c

df3 = pd.read_csv('results_baseline.csv', sep = ';')

min_rmse3 = np.min(df3['RMSE'])

df3[df3['RMSE'] == min_rmse3]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jyjsdvcQireEUqiy8O0aE-kgMkFYEy5c
# To: /content/results_baseline.csv
# 100% 749/749 [00:00<00:00, 979kB/s]
#     Unnamed: 0  lambda      RMSE        Time
# 15          15  1000.0  1.118448  116.648124

# %%
np.mean(df3['Time'])/60
# Out:
# 1.781061158577601

# %% [markdown]
# # SVD-AL

# %%
# !gdown 1orzbH-mYXiF0bNqmi-3BJoINFjnq-kaS

df4 = pd.read_csv('results_SVD-AL.csv', sep = ';')

min_rmse4 = np.min(df4['RMSE'])

df4[df4['RMSE'] == min_rmse4]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1orzbH-mYXiF0bNqmi-3BJoINFjnq-kaS
# To: /content/results_SVD-AL.csv
# 100% 2.44k/2.44k [00:00<00:00, 1.67MB/s]
#    Unnamed: 0       input type  factors      RMSE  Time Train  Time Validation
# 4           4  inputGlobalMean      100  1.109921     5.29031        93.407408

# %% [markdown]
# # SVD-GD

# %% [markdown]
# # FBC-kNN

# %% [markdown]
# ## FBC-kNN Gêneros

# %%
# !gdown 1TIuZCu0I6bOnUHVT_XJapXbAZiHeEkTv

df5 = pd.read_csv('results_FBCKNN_genres.csv', sep = ';')

min_rmse5 = np.min(df5['RMSE'])

df5[df5['RMSE'] == min_rmse5]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TIuZCu0I6bOnUHVT_XJapXbAZiHeEkTv
# To: /content/results_FBCKNN_genres.csv
# 100% 2.13k/2.13k [00:00<00:00, 2.69MB/s]
#     Unnamed: 0   k      RMSE         Time
# 11          11  12  1.227183  1133.320373

# %%
np.mean(df5['Time'])/60
# Out:
# 19.28677871648957

# %% [markdown]
# ## FBCkNN TFIDF

# %%
# !gdown 1LP9nvQ29o0Pghl6iBD_BUSh1qoek8CfF

df6 = pd.read_csv('results_FBCKNN_tfidf.csv', sep = ';')

min_rmse6 = np.min(df6['RMSE'])

df6[df6['RMSE'] == min_rmse6].loc[0]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LP9nvQ29o0Pghl6iBD_BUSh1qoek8CfF
# To: /content/results_FBCKNN_tfidf.csv
# 100% 2.14k/2.14k [00:00<00:00, 2.74MB/s]
# Unnamed: 0       0.000000
# k                1.000000
# RMSE             2.819472
# Time          1147.564158
# Name: 0, dtype: float64

# %%
np.mean(df6['Time'])/60
# Out:
# 19.604409338584563

# %% [markdown]
# ## FBCkNN BERT

# %%
# !gdown 1Jmpof4EfGtM5Ld8zVbOmAgx3IrbluAF0

df7 = pd.read_csv('results_FBCKNN_BERT.csv', sep = ';')

min_rmse7 = np.min(df7['RMSE'])

df7[df7['RMSE'] == min_rmse7]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Jmpof4EfGtM5Ld8zVbOmAgx3IrbluAF0
# To: /content/results_FBCKNN_BERT.csv
# 100% 2.10k/2.10k [00:00<00:00, 2.76MB/s]
#    Unnamed: 0  k      RMSE         Time
# 8           8  9  1.109915  1180.026891

# %%
np.mean(df7['Time'])/60
# Out:
# 19.632707483752245

# %% [markdown]
# # Hibridização

# %%
# !gdown 1XXUDdibi4RZQUUB_A4UkbN9C7QxWd9j9

df8 = pd.read_csv('results_FHib.csv', sep = ';')

min_rmse8 = np.min(df8['RMSE'])

df8[df8['RMSE'] == min_rmse8]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XXUDdibi4RZQUUB_A4UkbN9C7QxWd9j9
# To: /content/results_FHib.csv
# 100% 2.13k/2.13k [00:00<00:00, 3.52MB/s]
#    Unnamed: 0  k      RMSE         Time
# 0           0  1  1.182569  1956.804137
# 1           1  2  1.182569  1936.057653
# 2           2  3  1.182569  1934.542566

# %%
np.mean(df8['Time'])/60
# Out:
# 32.38556371862386
